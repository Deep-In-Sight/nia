# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import matplotlib.pyplot as plt 

import cv2
import json

from pathlib import Path
from glob import glob

import json
import nia22
from nia22 import utils
from nia22.mask_utils import gen_mask

# %%
# Load annotation
base_dir = Path("/home/hoseung/Work/NIA/") 
json_dir = base_dir / Path("data/json/")
raw_dir = base_dir / Path("data/raw/")

# %%
# dkey <-> device
conditions = ["F", "S", "D", "A", "N"]
postures = ["S", "D", "P", "L", "F", "C", "H", "E", "T", "U"]
device = ["S", "T", "L", "V", "M"]

dir_names = ["Eye-tracker/", "FaceAngle/", 
             "CamAngle/", "DistCam2Face/", 
             "DistDisp2Face/"]
file_names = ["_point_", "_head_", "_cam_", 
              "_dcam_", "_ddisp_"]

# %%
vl = utils.VidLoader(base_dir)
# Out:
# Base dir: /home/hoseung/Work/NIA/data/raw

# %%
#data dir
dout_dir = base_dir / Path("data/rit_data")
os.makedirs(dout_dir, exist_ok=True)

# cropped img 
png_dir = str(dout_dir / Path("images/")) + '/'
os.makedirs(png_dir, exist_ok=True)

# npy label
label_dir = str(dout_dir / Path("labels/")) + '/'
os.makedirs(label_dir, exist_ok=True)

# %%
for uid in range(131, 168):
    for device in ["L", "M", "V", "T", "S"][2:3]:
        vlist = vl.load(uid, device=device)
        # save PNG 
        for fn_vid in vlist:
            fn_base = fn_vid.split("/")[-1].split(".mp4")[0]
            cap = cv2.VideoCapture(fn_vid)
            if cap.isOpened():
                jlist = vl.get_jsons(fn_vid)
                for ff, fn_json in zip(jlist['frames'], jlist['jsons']):
                    try:
                        anno = json.load(open(fn_json,"r"))
                        cap.set(cv2.CAP_PROP_POS_FRAMES, ff)
                        ok, frame = cap.read()
                        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

                        fn_png_out = str(fn_base) + f"_{ff}"
                        err = gen_mask(frame, anno, fn_png_out, png_dir, label_dir)
                    except:
                        print("something wrong", fn_json)
            else:
                print("Can't open video file")
                print(">>>", fn_vid)
            cap.release()
            print(fn_vid, "done")
# Out:
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_*_V_rgb_*_*_*.mp4
# Found 57 videos
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_F_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_D_U_T.mp4 done
# NIA22EYE_S1_131_T1_S01_V_rgb_A_D_T_51
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S01_V_rgb_A_D_T_128
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S01_V_rgb_A_D_T_229
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_A_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_D_U_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_N_E_T.mp4 done
# NIA22EYE_S1_131_T1_S02_V_rgb_D_U_T_99
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S02_V_rgb_D_U_T_167
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S02_V_rgb_D_U_T_220
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_D_U_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_N_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_F_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_F_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_D_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_A_E_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_F_E_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_D_C_T.mp4 done
# NIA22EYE_S1_131_T1_S03_V_rgb_N_U_T_249
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_N_U_T.mp4 done
# NIA22EYE_S1_131_T1_S02_V_rgb_D_C_T_132
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_D_C_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_A_U_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_N_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_N_E_T.mp4 done
# NIA22EYE_S1_131_T1_S01_V_rgb_N_D_T_260
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S01_V_rgb_N_D_T_262
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_N_D_T.mp4 done
# NIA22EYE_S1_131_T1_S03_V_rgb_S_D_T_233
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S03_V_rgb_S_D_T_237
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_S_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_S_C_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_F_H_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_N_E_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_F_H_T.mp4 done
# NIA22EYE_S1_131_T1_S03_V_rgb_S_E_T_34
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S03_V_rgb_S_E_T_43
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S03_V_rgb_S_E_T_113
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_S_E_T.mp4 done
# NIA22EYE_S1_131_T1_S01_V_rgb_S_E_T_115
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S01_V_rgb_S_E_T_235
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S01_V_rgb_S_E_T_236
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_S_E_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_A_E_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_A_C_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_N_U_T.mp4 done
# NIA22EYE_S1_131_T1_S02_V_rgb_N_U_T_146
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_N_U_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_D_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_F_E_T.mp4 done
# NIA22EYE_S1_131_T1_S02_V_rgb_F_U_T_68
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_F_U_T.mp4 done
# NIA22EYE_S1_131_T1_S01_V_rgb_F_U_T_156
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_F_U_T.mp4 done
# NIA22EYE_S1_131_T1_S02_V_rgb_S_E_T_236
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_S_E_T.mp4 done
# NIA22EYE_S1_131_T1_S03_V_rgb_A_U_T_107
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S03_V_rgb_A_U_T_281
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_A_U_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_F_H_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_F_C_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_D_E_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_A_U_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_S_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S02_V_rgb_A_D_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_F_E_T.mp4 done
# NIA22EYE_S1_131_T1_S03_V_rgb_S_C_T_42
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S03_V_rgb_S_C_T_231
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_S_C_T.mp4 done
# NIA22EYE_S1_131_T1_S01_V_rgb_A_C_T_78
# not enough labels. Eyes are closed?
# NIA22EYE_S1_131_T1_S01_V_rgb_A_C_T_224
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_A_C_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_F_C_T.mp4 done
# NIA22EYE_S1_131_T1_S01_V_rgb_S_C_T_224
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_S_C_T.mp4 done
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S03_V_rgb_D_C_T.mp4 done
# NIA22EYE_S1_131_T1_S01_V_rgb_D_E_T_89
# not enough labels. Eyes are closed?
# /home/hoseung/Work/NIA/data/raw/131/T1/VehicleLCD/RGB/NIA22EYE_S1_131_T1_S01_V_rgb_D_E_T.mp4 done
